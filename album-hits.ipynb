# %%
from scrape_lyrics import *

# %%
# songs = scrape_album_songs('kanye-west', 'my-beautiful-dark-twisted-fantasy')

# %%
# scrape_lyrics_to_csv('kanye-west','Dark Fantasy', 'https://genius.com/Kanye-west-dark-fantasy-lyrics')

# %%
pd.read_csv('lyrics.csv', header=None)
# Out:
#              0                                            1  \
# 0   kanye-west                                 Dark Fantasy
# 1   kanye-west                                     Gorgeous
# 2   kanye-west                                        POWER
# 3   kanye-west                All of the Lights (Interlude)
# 4   kanye-west                            All of the Lights
# 5   kanye-west                                      Monster
# 6   kanye-west                                  So Appalled
# 7   kanye-west                         Devil in a New Dress
# 8   kanye-west                                      Runaway
# 9   kanye-west                               Hell of a Life
# 10  kanye-west                                   Blame Game
# 11  kanye-west                            Lost in the World
# 12  kanye-west                  Who Will Survive in America
# 13  kanye-west                                   See Me Now
# 14  kanye-west  My Beautiful Dark Twisted Fantasy [Booklet]
# ...

# %%
x = [('Kanye West', 'my beautiful-Dark-twisted-fantasy')]

# %%
scrape_all(x)
